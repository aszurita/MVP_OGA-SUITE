# %%
import pandas as pd

# %%
df = pd.read_csv(
    'Z_INF_TECNICA_FICHAS (1).txt',
    sep=r'\|\|',
    engine='python',
    dtype=str
)
df.head()
df.to_csv('Z_INF_TECNICA_FICHAS.csv', index=False)
